# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
from bs4 import BeautifulSoup
url="http://www.spencersretail.com/store-list?spencer_type=1"
r=requests.get(url)
htmlContent=r.content
print(htmlContent)
# Out:
# b'<!doctype html>\n<html class="no-js" lang="en" dir="ltr">\n<head>\n<meta charset="utf-8">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta http-equiv="ImageToolbar" content="false">\n<meta name="viewport" content="width=device-width, maximum-scale = 1.0">\n\n<meta name="description" content="Spencer\'s Retail is a leading retailer that operates multiple retail formats in India." />\n<meta name="keywords" content="retail, brands, retail stores, value retail, retail formats, 2beme, spencer" />\n<meta name="google-site-verification" content="tW2loRdW-1hFS8zsM3Jg075zEQ0FeBxk9BjUITTw-Bg" />\n\n<link rel="shortcut icon" href="/img/spencersicon.jpg">\n<!--<link rel="alternate" title="Spencer\'s Retail RSS" href="http://www.spencersretail.com/rss.xml">-->\n<meta property="og:title" content="Store List" />\r\n<meta name="twitter:title" content="Store List" />\r\n<title>Spencer\'s Retail is a leading retailer that operates multiple retail formats in India.</title> <link rel="sty
# ...

# %%
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(htmlContent, 'html.parser')
print(soup)
with open('leptonsoup.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="false" http-equiv="ImageToolbar"/>
# <meta content="width=device-width, maximum-scale = 1.0" name="viewport"/>
# <meta content="Spencer's Retail is a leading retailer that operates multiple retail formats in India." name="description">
# <meta content="retail, brands, retail stores, value retail, retail formats, 2beme, spencer" name="keywords">
# <meta content="tW2loRdW-1hFS8zsM3Jg075zEQ0FeBxk9BjUITTw-Bg" name="google-site-verification">
# <link href="/img/spencersicon.jpg" rel="shortcut icon"/>
# <!--<link rel="alternate" title="Spencer's Retail RSS" href="http://www.spencersretail.com/rss.xml">-->
# <meta content="Store List" property="og:title">
# <meta content="Store List" name="twitter:title"/>
# ...

# %%
for link in anchors:
    print(link.get('href'))
# Out:
# /
# #
# #
# /about-us
# /heritage
# /milestones
# /formats
# /differentiators
# /ambience
# /investor
# /own-brands
# #
# /category/food
# /category/personal-care
# /category/home
# /category/electronics-and-electricals
# /category/fashion-and-accessories
# /category/specialities
# /category/what-we-do-differently
# /store-list
# http://corporate.spencersretail.com/
# /offers-month
# /spencers-smart-rewards
# /spencers-gift-card
# http://rp-sg.in/
# /
# #
# http://www.spencersretail.com/stores/spencers-neighborhood-store-aliganj-lucknow
# http://www.spencersretail.com/stores/spencer?s-neighborhood-store-rajahmundryandhra-pradesh
# http://www.spencersretail.com/stores/spencers-neighborhood-store-m-g-roadtrivandrum
# http://www.spencersretail.com/stores/spencers-neighborhood-store-sreekaryamtrivandrum
# http://www.spencersretail.com/stores/spencers-neighborhood-store-pattomtrivandrum
# http://www.spencersretail.com/stores/spencers-neighborhood-store-vellayambalamtrivandrum
# ...

# %%
# Parse the HTML code with BeautifulSoup
soup = BeautifulSoup(htmlContent, 'html.parser')

# Find all div elements with class 'views-row storebox'
storeboxes = soup.find_all('div', {'class': 'views-row storebox'})

# Loop through each store location and extract the address information
for storebox in storeboxes:
    location_div = storebox.find('div', {'class': 'location vcard'})
    store_name = location_div.find('span', {'class': 'fn'}).text.strip()
    address = location_div.find('div', {'class': 'street-address'}).text.strip()
    additional_address = location_div.find('span', {'class': 'additional'})
    if additional_address:
        address += ' ' + additional_address.text.strip()
    postal_code = location_div.find('span', {'class': 'postal-code'}).text.strip()
    locality = location_div.find('span', {'class': 'locality'}).text.strip()
    region = location_div.find('span', {'class': 'region'}).text.strip()
    country = location_div.find('div', {'class': 'country-name'}).text.strip()
    phone_number = location_div.find('span', {'class': 'value'}).text.strip()

    # Extract timings
    opens_at_div = storebox.find('div', {'class': 'views-field-field-opens-at'})
    closes_at_div = storebox.find('div', {'class': 'views-field-field-closes-at'})
    if opens_at_div and closes_at_div:
        opens_at = opens_at_div.find('div', {'class': 'field-content'}).text.strip()
        closes_at = closes_at_div.find('div', {'class': 'field-content'}).text.strip()
    else:
        opens_at = 'N/A'
        closes_at = 'N/A'

    # Print the extracted information
    print('Store Name:', store_name)
    print('Address:', address)
    print('Postal Code:', postal_code)
    print('Locality:', locality)
    print('Region:', region)
    print('Country:', country)
    print('Phone Number:', phone_number)
    print('Opens At:', opens_at)
    print('Closes At:', closes_at)
    print('---------------------------')
# Out:
# Store Name: Spencer's Neighborhood Store
# Address: Spencer Retail Limited, HIG-2, Near Ram Ram Bank Chowk  Sector Q, Aliganj
# Postal Code: 226024
# Locality: Lucknow
# Region: Uttar Pradesh
# Country: India
# Phone Number:
# Opens At: N/A
# Closes At: N/A
# ---------------------------
# Store Name: Spencer's Neighborhood Store
# Address: Spencers Retail Limited,Door No:69-31-15/1,Survey No.127 &129, Plot No 56,37,38  GNT Road
# Land mark SB motors Land mark SB motors
# Postal Code: 533101
# Locality: Rajahmundry
# Region: Andhra Pradesh
# Country: India
# Phone Number: 0883 6900540
# Opens At: 9:30 AM
# Closes At: 9:30 PM
# ---------------------------
# Store Name: Spencer's Neighborhood Store
# Address: Spencer Retail Limited,Spencer Junction, M G Road
# Postal Code: 695001
# Locality: Trivandrum
# Region: Kerala
# Country: India
# Phone Number: 0471-6451300
# Opens At: 7:30 AM
# Closes At: 21:30 PM
# ---------------------------
# Store Name: Spencer's Neighborhood Store
# ...
